# %% [markdown]
# # Baseline Model w/ only numerical data

# %% [markdown]
# ## 1. Import Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from kmodes.kmodes import KModes

# %% [markdown]
# ## 2. Import Dataset

# %%
df = pd.read_csv('../data/tese.csv', sep='|')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   account_id                                  50000 non-null  object
#  1   country_name                                50000 non-null  object
#  2   account_category                            50000 non-null  object
#  3   bi_account_classification                   50000 non-null  object
#  4   customer_type                               50000 non-null  object
#  5   company_name                                49995 non-null  object
#  6   domain                                      49945 non-null  object
#  7   city                                        49965 non-null  object
#  8   sic_code                                    22107 non-null  float64
#  9   companydataprovider_companyname             34549 non-null  object
#  10  companydataprovider_siccode                 33905 non-null  float64
#  11  companydataprovider_employeenumber          34550 non-null  float64
#  12  companydataprovider_revenue_in_eur          33741 non-null  float64
#  13  teamviewer_location                         50000 non-null  object
#  14  number_distinct_active_licenses             50000 non-null  int64
#  15  major_edition                               49775 non-null  object
#  16  initial_version                             48411 non-null  float64
#  17  current_version                             50000 non-null  int64
#  18  initial_edition                             49322 non-null  object
#  19  current_edition                             48759 non-null  object
#  20  number_rm_licenses                          50000 non-null  int64
#  21  number_rm_malwarebytes_endpoint_protection  50000 non-null  int64
#  22  number_pilot_licenses                       50000 non-null  int64
#  23  number_arassist_licenses                    50000 non-null  int64
#  24  number_frontline_licenses                   50000 non-null  int64
#  25  number_tvmeeting_licenses                   50000 non-null  int64
#  26  number_iot_licenses                         50000 non-null  int64
#  27  number_servicecamp_licenses                 50000 non-null  int64
#  28  number_remoteaccess_licenses                50000 non-null  int64
#  29  number_remoteaccess_subsc_licenses          50000 non-null  int64
#  30  number_business_licenses                    50000 non-null  int64
#  31  number_business_subsc_licenses              50000 non-null  int64
#  32  number_premium_licenses                     50000 non-null  int64
#  33  number_premium_subsc_licenses               50000 non-null  int64
#  34  number_corporate_licenses                   50000 non-null  int64
#  35  number_corporate_subsc_licenses             50000 non-null  int64
#  36  number_tensor_licenses                      50000 non-null  int64
#  37  total_connections_12m                       50000 non-null  int64
#  38  total_endpoints_12m                         50000 non-null  int64
#  39  total_devices_12m                           50000 non-null  int64
#  40  last_invoice_date_created                   50000 non-null  object
#  41  days_from_last_invoice                      50000 non-null  int64
#  42  current_sales_channel                       50000 non-null  object
#  43  age_customer                                50000 non-null  int64
#  44  number_renewals                             50000 non-null  int64
#  45  number_total_invoices                       50000 non-null  int64
#  46  account_value_in_eur                        50000 non-null  float64
#  47  revenue_last_12_month                       50000 non-null  float64
#  48  years_purchased                             50000 non-null  int64
#  49  billings_ltm_prorated                       50000 non-null  float64
#  50  business_model                              50000 non-null  object
#  51  is_subscription                             50000 non-null  bool
#  52  is_customer_perpetual                       50000 non-null  bool
# dtypes: bool(2), float64(8), int64(27), object(16)
# memory usage: 19.6+ MB

# %%
df.head()
# Out:
#                              account_id country_name account_category  \
# 0  3609465D-A808-EB11-95AA-005056A7C91D       Brazil         Standard
# 1  3657E19B-FD1A-E411-80D3-005056846F2F      Germany         Standard
# 2  8451D3C3-FC1A-E411-80D3-005056846F2F        Italy         Standard
# 3  B6B0B074-213F-ED11-9DB0-000D3ADEAD35  Netherlands         Standard
# 4  3151AAFA-F21A-E411-80D3-005056846F2F  Switzerland         Standard
#
#   bi_account_classification customer_type                       company_name  \
# 0              Inside Sales      Customer      Guaçu S/A Papeis e Embalagens
# 1              Inside Sales      Customer          Stadtwerke Bad Schwalbach
# 2              Inside Sales      Customer       Prussiani Engineering s.r.l.
# 3              Inside Sales      Customer  Kadoelenwerf Jachtservice & Haven
# 4              Inside Sales      Customer                   Casinò Lugano SA
#
#                domain                    city  sic_code  \
# 0       @guacu.com.br            estiva gerbi       NaN
# 1  @bad-schwalbach.de          Bad Schwalbach       NaN
# 2      @prussiani.com  Albano Sant'Alessandro    3559.0
# 3        @hotmail.com               Amsterdam    4493.0
# 4    @casinolugano.ch                  Lugano    7999.0
#
#   companydataprovider_companyname  ...  age_customer  number_renewals  \
# 0                             NaN  ...             3                3
# 1    Stadtwerke Schwalbach/Taunus  ...             9                2
# 2       PRUSSIANI ENGINEERING SPA  ...            13                2
# 3    Jachthaven Kadoelenwerf c.v.  ...             1                1
# 4                Casinò Lugano SA  ...            12                5
#
#    number_total_invoices account_value_in_eur  revenue_last_12_month  \
# 0                      4               822.49                 215.03
# 1                      4              2937.39                 837.22
# 2                      6              5884.78                1157.72
# 3                      2               861.84                 478.80
# 4                      7              3538.54                 533.25
#
#   years_purchased  billings_ltm_prorated  business_model is_subscription  \
# 0            8086                 215.03               S            True
# 1            8080                 837.22               S            True
# 2           12106                1157.72               S            True
# 3            4045                 478.80               S            True
# 4           14134                 533.25               S            True
#
#   is_customer_perpetual
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 53 columns]

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3.1. Add SIC Code & Description

# %%
df_sic_codes = pd.read_excel('../data/sic_4_digit_codes.xls')

# %%
df_sic_codes
# Out:
#       Code Value                                   Description
# 0            111                                         Wheat
# 1            112                                          Rice
# 2            115                                          Corn
# 3            116                                      Soybeans
# 4            119                              Cash grains, nec
# ...          ...                                           ...
# 1000        9651  Regulation, miscellaneous commercial sectors
# 1001        9661                 Space research and technology
# 1002        9711                             National security
# 1003        9721                         International affairs
# 1004        9999                Nonclassifiable establishments
#
# [1005 rows x 2 columns]

# %%
# Merge df and df_sic_codes and add the 'description' column to df
df = df.merge(df_sic_codes, left_on='sic_code', right_on='Code Value', how='left')

# %%
# Rename the 'description' column to 'code_description'
df.rename(columns={'Description': 'sic_code_description'}, inplace=True)

# %% [markdown]
# ### 3.2. Add Industry

# %%
# Define a dictionary to map SIC code ranges to major industry groups
major_groups = {
    range(1, 10): 'Agriculture, Forestry, and Fishing',
    range(10, 15): 'Mining',
    range(15, 18): 'Construction',
    range(20, 40): 'Manufacturing',
    range(40, 50): 'Transportation, Communications, Electric, Gas, and Sanitary Services',
    range(50, 53): 'Wholesale Trade',
    range(52, 60): 'Retail Trade',
    range(60, 68): 'Finance, Insurance, and Real Estate',
    range(70, 90): 'Services',
    range(90, 100): 'Public Administration'
}

# Map SIC code ranges to major industry group descriptions
def map_to_major_group(sic_code):
    for group_range, description in major_groups.items():
        if sic_code // 100 in group_range:
            return description
    return 'Unknown'

# %%
df['industry'] = df['sic_code'].apply(map_to_major_group)

# %%
df.head()
# Out:
#                              account_id country_name account_category  \
# 0  3609465D-A808-EB11-95AA-005056A7C91D       Brazil         Standard
# 1  3657E19B-FD1A-E411-80D3-005056846F2F      Germany         Standard
# 2  8451D3C3-FC1A-E411-80D3-005056846F2F        Italy         Standard
# 3  B6B0B074-213F-ED11-9DB0-000D3ADEAD35  Netherlands         Standard
# 4  3151AAFA-F21A-E411-80D3-005056846F2F  Switzerland         Standard
#
#   bi_account_classification customer_type                       company_name  \
# 0              Inside Sales      Customer      Guaçu S/A Papeis e Embalagens
# 1              Inside Sales      Customer          Stadtwerke Bad Schwalbach
# 2              Inside Sales      Customer       Prussiani Engineering s.r.l.
# 3              Inside Sales      Customer  Kadoelenwerf Jachtservice & Haven
# 4              Inside Sales      Customer                   Casinò Lugano SA
#
#                domain                    city  sic_code  \
# 0       @guacu.com.br            estiva gerbi       NaN
# 1  @bad-schwalbach.de          Bad Schwalbach       NaN
# 2      @prussiani.com  Albano Sant'Alessandro    3559.0
# 3        @hotmail.com               Amsterdam    4493.0
# 4    @casinolugano.ch                  Lugano    7999.0
#
#   companydataprovider_companyname  ...  account_value_in_eur  \
# 0                             NaN  ...                822.49
# 1    Stadtwerke Schwalbach/Taunus  ...               2937.39
# 2       PRUSSIANI ENGINEERING SPA  ...               5884.78
# 3    Jachthaven Kadoelenwerf c.v.  ...                861.84
# 4                Casinò Lugano SA  ...               3538.54
#
#    revenue_last_12_month  years_purchased billings_ltm_prorated  \
# 0                 215.03             8086                215.03
# 1                 837.22             8080                837.22
# 2                1157.72            12106               1157.72
# 3                 478.80             4045                478.80
# 4                 533.25            14134                533.25
#
#    business_model is_subscription  is_customer_perpetual  Code Value  \
# 0               S            True                  False         NaN
# 1               S            True                  False         NaN
# 2               S            True                  False      3559.0
# 3               S            True                  False      4493.0
# 4               S            True                  False      7999.0
#
#               sic_code_description  \
# 0                              NaN
# 1                              NaN
# 2  Special industry machinery, nec
# 3                          Marinas
# 4    Amusement and recreation, nec
#
#                                             industry
# 0                                            Unknown
# 1                                            Unknown
# 2                                      Manufacturing
# 3  Transportation, Communications, Electric, Gas,...
# 4                                           Services
#
# [5 rows x 56 columns]

# %% [markdown]
# ### 3.3. Cleaning

# %% [markdown]
# We will be working with only *non-null* values.

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18150 entries, 2 to 49998
# Data columns (total 56 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   account_id                                  18150 non-null  object
#  1   country_name                                18150 non-null  object
#  2   account_category                            18150 non-null  object
#  3   bi_account_classification                   18150 non-null  object
#  4   customer_type                               18150 non-null  object
#  5   company_name                                18150 non-null  object
#  6   domain                                      18150 non-null  object
#  7   city                                        18150 non-null  object
#  8   sic_code                                    18150 non-null  float64
#  9   companydataprovider_companyname             18150 non-null  object
#  10  companydataprovider_siccode                 18150 non-null  float64
#  11  companydataprovider_employeenumber          18150 non-null  float64
#  12  companydataprovider_revenue_in_eur          18150 non-null  float64
#  13  teamviewer_location                         18150 non-null  object
#  14  number_distinct_active_licenses             18150 non-null  int64
#  15  major_edition                               18150 non-null  object
#  16  initial_version                             18150 non-null  float64
#  17  current_version                             18150 non-null  int64
#  18  initial_edition                             18150 non-null  object
#  19  current_edition                             18150 non-null  object
#  20  number_rm_licenses                          18150 non-null  int64
#  21  number_rm_malwarebytes_endpoint_protection  18150 non-null  int64
#  22  number_pilot_licenses                       18150 non-null  int64
#  23  number_arassist_licenses                    18150 non-null  int64
#  24  number_frontline_licenses                   18150 non-null  int64
#  25  number_tvmeeting_licenses                   18150 non-null  int64
#  26  number_iot_licenses                         18150 non-null  int64
#  27  number_servicecamp_licenses                 18150 non-null  int64
#  28  number_remoteaccess_licenses                18150 non-null  int64
#  29  number_remoteaccess_subsc_licenses          18150 non-null  int64
#  30  number_business_licenses                    18150 non-null  int64
#  31  number_business_subsc_licenses              18150 non-null  int64
#  32  number_premium_licenses                     18150 non-null  int64
#  33  number_premium_subsc_licenses               18150 non-null  int64
#  34  number_corporate_licenses                   18150 non-null  int64
#  35  number_corporate_subsc_licenses             18150 non-null  int64
#  36  number_tensor_licenses                      18150 non-null  int64
#  37  total_connections_12m                       18150 non-null  int64
#  38  total_endpoints_12m                         18150 non-null  int64
#  39  total_devices_12m                           18150 non-null  int64
#  40  last_invoice_date_created                   18150 non-null  object
#  41  days_from_last_invoice                      18150 non-null  int64
#  42  current_sales_channel                       18150 non-null  object
#  43  age_customer                                18150 non-null  int64
#  44  number_renewals                             18150 non-null  int64
#  45  number_total_invoices                       18150 non-null  int64
#  46  account_value_in_eur                        18150 non-null  float64
#  47  revenue_last_12_month                       18150 non-null  float64
#  48  years_purchased                             18150 non-null  int64
#  49  billings_ltm_prorated                       18150 non-null  float64
#  50  business_model                              18150 non-null  object
#  51  is_subscription                             18150 non-null  bool
#  52  is_customer_perpetual                       18150 non-null  bool
#  53  Code Value                                  18150 non-null  float64
#  54  sic_code_description                        18150 non-null  object
#  55  industry                                    18150 non-null  object
# dtypes: bool(2), float64(9), int64(27), object(18)
# memory usage: 7.7+ MB

# %%
# Separate categorical features
data = df.select_dtypes(include='object')

# %%
data
# Out:
#                                  account_id   country_name account_category  \
# 2      8451D3C3-FC1A-E411-80D3-005056846F2F          Italy         Standard
# 3      B6B0B074-213F-ED11-9DB0-000D3ADEAD35    Netherlands         Standard
# 4      3151AAFA-F21A-E411-80D3-005056846F2F    Switzerland         Standard
# 5      7CA97D7A-A1F0-EC11-BB3D-000D3AB57339  United States         Standard
# 7      FFE48D4C-A666-EA11-A811-000D3AB11761         France         Standard
# ...                                     ...            ...              ...
# 49969  9DC5CDED-C898-ED11-AAD1-000D3ADEA83D        Austria         Standard
# 49973  D0B6E4F9-E81A-E411-80D3-005056846F2F  United States         Standard
# 49981  8CD2F113-BF75-EB11-A812-000D3AB25E8C         France         Standard
# 49994  95C51C1D-A4D6-E711-80EF-005056844077  United States         Standard
# 49998  952309B8-21A5-E811-8108-005056844077         Poland         Standard
#
#       bi_account_classification customer_type  \
# 2                  Inside Sales      Customer
# 3                  Inside Sales      Customer
# 4                  Inside Sales      Customer
# 5                  Inside Sales      Customer
# 7                  Inside Sales      Customer
# ...                         ...           ...
# 49969              Inside Sales      Customer
# 49973              Inside Sales      Customer
# 49981              Inside Sales      Customer
# 49994              Inside Sales      Customer
# 49998              Inside Sales      Customer
#
#                                   company_name             domain  \
# 2                 Prussiani Engineering s.r.l.     @prussiani.com
# 3            Kadoelenwerf Jachtservice & Haven       @hotmail.com
# 4                             Casinò Lugano SA   @casinolugano.ch
# 5                          Delaney's Irish Pub    @delaneystx.com
# 7                                          smt        @wanadoo.fr
# ...                                        ...                ...
# 49969  Mineralstoffverwertungsgesellschaft mbH  @wienerberger.com
# 49973                        Authenticom, Inc.   @authenticom.com
# 49981            Etablissement Gerace Peinture         @gmail.com
# 49994                            Velociti Inc.      @velociti.com
# 49998          Firma AKOM Aleksander Tarkowski           @akom.pl
#
#                          city          companydataprovider_companyname  \
# 2      Albano Sant'Alessandro                PRUSSIANI ENGINEERING SPA
# 3                   Amsterdam             Jachthaven Kadoelenwerf c.v.
# 4                      Lugano                         Casinò Lugano SA
# 5                    McKinney                      Delaney's Irish Pub
# 7                       paris                                      SMT
# ...                       ...                                      ...
# 49969                    Wien  Mineralstoffverwertungsgesellschaft mbH
# 49973               La Crosse                              Authenticom
# 49981                  Grasse           ETABLISSEMENTS GERACE PEINTURE
# 49994               Riverside                                 velocity
# 49998             Częstochowa          FIRMA AKOM ALEKSANDER TARKOWSKI
#
#       teamviewer_location  major_edition initial_edition current_edition  \
# 2                    EMEA      Corporate         Premium       Corporate
# 3                    EMEA       Business        Business        Business
# 4                    EMEA       Business        Business        Business
# 5                AMERICAS  Remote Access   Remote Access   Remote Access
# 7                    EMEA  Remote Access   Remote Access   Remote Access
# ...                   ...            ...             ...             ...
# 49969                EMEA  Remote Access   Remote Access   Remote Access
# 49973            AMERICAS      Corporate       Corporate       Corporate
# 49981                EMEA       Business        Business        Business
# 49994            AMERICAS      Corporate       Corporate       Corporate
# 49998                EMEA       Business        Business        Business
#
#       last_invoice_date_created current_sales_channel business_model  \
# 2           2023-08-31 02:06:03          Inside Sales              S
# 3           2023-09-28 03:58:39          Inside Sales              S
# 4           2023-06-28 03:00:04               Webshop              S
# 5           2023-06-20 03:30:54               Webshop              S
# 7           2023-03-15 02:46:59               Webshop              S
# ...                         ...                   ...            ...
# 49969       2023-06-16 07:40:19               Webshop              S
# 49973       2023-05-23 02:31:49          Inside Sales              S
# 49981       2023-02-25 02:17:03          Inside Sales              S
# 49994       2023-02-04 03:07:34          Inside Sales              S
# 49998       2023-08-21 01:15:18               Webshop              S
#
#                        sic_code_description  \
# 2           Special industry machinery, nec
# 3                                   Marinas
# 4             Amusement and recreation, nec
# 5                           Drinking places
# 7           Local trucking, without storage
# ...                                     ...
# 49969                        Refuse systems
# 49973       Data processing and preparation
# 49981            Painting and paper hanging
# 49994                         Services, nec
# 49998  Computers, peripherals, and software
#
#                                                 industry
# 2                                          Manufacturing
# 3      Transportation, Communications, Electric, Gas,...
# 4                                               Services
# 5                                           Retail Trade
# 7      Transportation, Communications, Electric, Gas,...
# ...                                                  ...
# 49969  Transportation, Communications, Electric, Gas,...
# 49973                                           Services
# 49981                                       Construction
# 49994                                           Services
# 49998                                    Wholesale Trade
#
# [18150 rows x 18 columns]

# %% [markdown]
# ### 3.4. Feature Selection

# %% [markdown]
# Write a little explanation about the selection method.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18150 entries, 2 to 49998
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       18150 non-null  object
#  1   country_name                     18150 non-null  object
#  2   account_category                 18150 non-null  object
#  3   bi_account_classification        18150 non-null  object
#  4   customer_type                    18150 non-null  object
#  5   company_name                     18150 non-null  object
#  6   domain                           18150 non-null  object
#  7   city                             18150 non-null  object
#  8   companydataprovider_companyname  18150 non-null  object
#  9   teamviewer_location              18150 non-null  object
#  10  major_edition                    18150 non-null  object
#  11  initial_edition                  18150 non-null  object
#  12  current_edition                  18150 non-null  object
#  13  last_invoice_date_created        18150 non-null  object
#  14  current_sales_channel            18150 non-null  object
#  15  business_model                   18150 non-null  object
#  16  sic_code_description             18150 non-null  object
#  17  industry                         18150 non-null  object
# dtypes: object(18)
# memory usage: 2.6+ MB

# %%
categorical_features = ['account_id', 'account_category', 'bi_account_classification',
       'customer_type', 'teamviewer_location', 'major_edition', 'current_sales_channel', 'business_model', 'industry']

data = data[categorical_features].copy()

data
# Out:
#                                  account_id account_category  \
# 2      8451D3C3-FC1A-E411-80D3-005056846F2F         Standard
# 3      B6B0B074-213F-ED11-9DB0-000D3ADEAD35         Standard
# 4      3151AAFA-F21A-E411-80D3-005056846F2F         Standard
# 5      7CA97D7A-A1F0-EC11-BB3D-000D3AB57339         Standard
# 7      FFE48D4C-A666-EA11-A811-000D3AB11761         Standard
# ...                                     ...              ...
# 49969  9DC5CDED-C898-ED11-AAD1-000D3ADEA83D         Standard
# 49973  D0B6E4F9-E81A-E411-80D3-005056846F2F         Standard
# 49981  8CD2F113-BF75-EB11-A812-000D3AB25E8C         Standard
# 49994  95C51C1D-A4D6-E711-80EF-005056844077         Standard
# 49998  952309B8-21A5-E811-8108-005056844077         Standard
#
#       bi_account_classification customer_type teamviewer_location  \
# 2                  Inside Sales      Customer                EMEA
# 3                  Inside Sales      Customer                EMEA
# 4                  Inside Sales      Customer                EMEA
# 5                  Inside Sales      Customer            AMERICAS
# 7                  Inside Sales      Customer                EMEA
# ...                         ...           ...                 ...
# 49969              Inside Sales      Customer                EMEA
# 49973              Inside Sales      Customer            AMERICAS
# 49981              Inside Sales      Customer                EMEA
# 49994              Inside Sales      Customer            AMERICAS
# 49998              Inside Sales      Customer                EMEA
#
#        major_edition current_sales_channel business_model  \
# 2          Corporate          Inside Sales              S
# 3           Business          Inside Sales              S
# 4           Business               Webshop              S
# 5      Remote Access               Webshop              S
# 7      Remote Access               Webshop              S
# ...              ...                   ...            ...
# 49969  Remote Access               Webshop              S
# 49973      Corporate          Inside Sales              S
# 49981       Business          Inside Sales              S
# 49994      Corporate          Inside Sales              S
# 49998       Business               Webshop              S
#
#                                                 industry
# 2                                          Manufacturing
# 3      Transportation, Communications, Electric, Gas,...
# 4                                               Services
# 5                                           Retail Trade
# 7      Transportation, Communications, Electric, Gas,...
# ...                                                  ...
# 49969  Transportation, Communications, Electric, Gas,...
# 49973                                           Services
# 49981                                       Construction
# 49994                                           Services
# 49998                                    Wholesale Trade
#
# [18150 rows x 9 columns]

# %% [markdown]
# ### 3.5. Feature Engineering

# %%
# Select the features (excluding the ID column)
features = data.iloc[:, 1:]

features
# Out:
#       account_category bi_account_classification customer_type  \
# 2             Standard              Inside Sales      Customer
# 3             Standard              Inside Sales      Customer
# 4             Standard              Inside Sales      Customer
# 5             Standard              Inside Sales      Customer
# 7             Standard              Inside Sales      Customer
# ...                ...                       ...           ...
# 49969         Standard              Inside Sales      Customer
# 49973         Standard              Inside Sales      Customer
# 49981         Standard              Inside Sales      Customer
# 49994         Standard              Inside Sales      Customer
# 49998         Standard              Inside Sales      Customer
#
#       teamviewer_location  major_edition current_sales_channel business_model  \
# 2                    EMEA      Corporate          Inside Sales              S
# 3                    EMEA       Business          Inside Sales              S
# 4                    EMEA       Business               Webshop              S
# 5                AMERICAS  Remote Access               Webshop              S
# 7                    EMEA  Remote Access               Webshop              S
# ...                   ...            ...                   ...            ...
# 49969                EMEA  Remote Access               Webshop              S
# 49973            AMERICAS      Corporate          Inside Sales              S
# 49981                EMEA       Business          Inside Sales              S
# 49994            AMERICAS      Corporate          Inside Sales              S
# 49998                EMEA       Business               Webshop              S
#
#                                                 industry
# 2                                          Manufacturing
# 3      Transportation, Communications, Electric, Gas,...
# 4                                               Services
# 5                                           Retail Trade
# 7      Transportation, Communications, Electric, Gas,...
# ...                                                  ...
# 49969  Transportation, Communications, Electric, Gas,...
# 49973                                           Services
# 49981                                       Construction
# 49994                                           Services
# 49998                                    Wholesale Trade
#
# [18150 rows x 8 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18150 entries, 2 to 49998
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   account_category           18150 non-null  object
#  1   bi_account_classification  18150 non-null  object
#  2   customer_type              18150 non-null  object
#  3   teamviewer_location        18150 non-null  object
#  4   major_edition              18150 non-null  object
#  5   current_sales_channel      18150 non-null  object
#  6   business_model             18150 non-null  object
#  7   industry                   18150 non-null  object
# dtypes: object(8)
# memory usage: 1.2+ MB

# %%
# Create an encoder
encoder = OneHotEncoder(sparse=False)  # Set sparse=False for easier handling

categorical_features = features.columns

# Fit the encoder on the features
encoded_data = encoder.fit_transform(data[categorical_features])

# %%
# statistics of scaled data
pd.DataFrame(encoded_data).describe()
# Out:
#                  0             1             2             3             4   \
# count  18150.000000  18150.000000  18150.000000  18150.000000  18150.000000
# mean       0.018402      0.002810      0.000551      0.978237      0.018402
# std        0.134404      0.052936      0.023467      0.145913      0.134404
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      1.000000      0.000000
# 50%        0.000000      0.000000      0.000000      1.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  18150.000000  18150.000000  18150.000000  18150.000000  18150.000000
# mean       0.940000      0.002810      0.004077      0.034711      0.957025
# std        0.237493      0.052936      0.063724      0.183051      0.202807
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.000000      1.000000
# 50%        1.000000      0.000000      0.000000      0.000000      1.000000
# 75%        1.000000      0.000000      0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...            29            30            31            32  \
# count  ...  18150.000000  18150.000000  18150.000000  18150.000000
# mean   ...      0.014435      0.059229      0.055096      0.168815
# std    ...      0.119280      0.236059      0.228175      0.374599
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#                  33            34            35            36            37  \
# count  18150.000000  18150.000000  18150.000000  18150.000000  18150.000000
# mean       0.003140      0.016364      0.083361      0.448209      0.050579
# std        0.055954      0.126873      0.276435      0.497324      0.219141
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  38
# count  18150.000000
# mean       0.100771
# std        0.301034
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 39 columns]

# %% [markdown]
# ### 3.6. Determine the number of clusters(k)

# %%
# Define a range of k values to test
k_range = range(1, 10)

# Create a list to store WCSS values
wcss = []

for k in k_range:
  # Create a KMeans object with the current k value
  kmeans = KMeans(n_clusters=k, init='k-means++', random_state=0)
  # Fit the model on the scaled features
  kmeans.fit(encoded_data)
  # Get the WCSS value (inertia_)
  wcss.append(kmeans.inertia_)

# %%
# Converting the results into a DataFrame
frame = pd.DataFrame({'Cluster':k_range, 'WCSS':wcss})

# Plot the WCSS vs k to identify the elbow point
plt.figure(figsize=(10, 8))
plt.plot(k_range, wcss, 'o-', markerfacecolor='lightblue', markeredgewidth=2, markersize=8)
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS (Within Cluster Sum of Squares)')
plt.title('Elbow Method for KMeans Clustering')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Modeling

# %% [markdown]
# ### 4.1. KModes

# %%
# Assuming your data is loaded into a pandas DataFrame called 'df'
kmodes_clusterer = KModes(n_clusters=5, init='Huang')
kmodes_clusterer.fit(features)

# Add the cluster labels to the original DataFrame
df['cluster'] = kmodes_clusterer.labels_

# %%
kmodes_model = KModes(n_clusters=5, init='Cao')

# 'Cao' initialization is a common strategy for categorical data
kmodes_result = kmodes_model.fit_predict(features)

# Add the cluster labels to the original DataFrame
df['cluster'] = kmodes_result

# %% [markdown]
# ### 4.1. KMeans

# %%
# Assuming k based on the Elbow Method
kmeans = KMeans(n_clusters=10, init='k-means++', random_state=0)
kmeans.fit(encoded_data)
pred = kmeans.predict(encoded_data)

# %%
# Value count of points in each of the above-formed clusters
frame = pd.DataFrame(encoded_data)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 1    6639
# 2    6028
# 7    4355
# 0     992
# 6      76
# 4      37
# 3      11
# 8      10
# 9       1
# 5       1
# Name: cluster, dtype: int64

# %%
# Assign the columns of new_points (xs and ys) for plotting (assuming 2D data)
xs = features_scaled[:, 0]
ys = features_scaled[:, 1]

# %%
# Make a scatter plot of xs and ys, using labels to define the colors
plt.scatter(xs, ys, c=pred, alpha=0.5)

# Assign the cluster centers: centroids
centroids = kmeans.cluster_centers_

# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]

# Make a scatter plot of centroids_x and centroids_y
plt.scatter(centroids_x, centroids_y, marker='D',s=50)
plt.show()

# %% [markdown]
# ### 4.2. DBSCAN

# %%
# Create visualization of the clusters

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ### 5.1. KMeans

# %%
silhouette_score(features_scaled, cluster_labels)
# Out:
# 0.41163754126815194

# %%
data['cluster'] = cluster_labels

data
# Out:
#                                  account_id  \
# 2      8451D3C3-FC1A-E411-80D3-005056846F2F
# 3      B6B0B074-213F-ED11-9DB0-000D3ADEAD35
# 4      3151AAFA-F21A-E411-80D3-005056846F2F
# 5      7CA97D7A-A1F0-EC11-BB3D-000D3AB57339
# 7      FFE48D4C-A666-EA11-A811-000D3AB11761
# ...                                     ...
# 49969  9DC5CDED-C898-ED11-AAD1-000D3ADEA83D
# 49973  D0B6E4F9-E81A-E411-80D3-005056846F2F
# 49981  8CD2F113-BF75-EB11-A812-000D3AB25E8C
# 49994  95C51C1D-A4D6-E711-80EF-005056844077
# 49998  952309B8-21A5-E811-8108-005056844077
#
#        companydataprovider_employeenumber  companydataprovider_revenue_in_eur  \
# 2                                    52.0                          15379307.0
# 3                                     3.0                             82742.0
# 4                                   242.0                          15454197.0
# 5                                     7.0                            830000.0
# 7                                    21.0                            985411.0
# ...                                   ...                                 ...
# 49969                                 9.0                           3111000.0
# 49973                               105.0                          18900000.0
# 49981                                 7.0                            930779.0
# 49994                                 5.0                            954000.0
# 49998                                 1.0                             26294.0
#
#        number_distinct_active_licenses  total_connections_12m  \
# 2                                    3                   3349
# 3                                    1                     78
# 4                                    1                    243
# 5                                    1                    944
# 7                                    1                      0
# ...                                ...                    ...
# 49969                                1                    297
# 49973                                3                   3512
# 49981                                1                    561
# 49994                                2                    775
# 49998                                1                    668
#
#        total_endpoints_12m  total_devices_12m  days_from_last_invoice  \
# 2                      611                 21                      85
# 3                        4                  2                      57
# 4                       33                  3                     149
# 5                        5                  7                     157
# 7                        0                  0                     254
# ...                    ...                ...                     ...
# 49969                    7                 16                     161
# 49973                 1578                168                     185
# 49981                    9                  2                     272
# 49994                   89                 22                     293
# 49998                  273                  4                      95
#
#        age_customer  number_renewals  number_total_invoices  \
# 2                13                2                      6
# 3                 1                1                      2
# 4                12                5                      7
# 5                 1                1                      2
# 7                 3                3                      4
# ...             ...              ...                    ...
# 49969             0                0                      2
# 49973            13                7                     12
# 49981             2                2                      3
# 49994            10                4                     15
# 49998             5                5                      6
#
#        account_value_in_eur  revenue_last_12_month  years_purchased  \
# 2                   5884.78                1157.72            12106
# 3                    861.84                 478.80             4045
# 4                   3538.54                 533.25            14134
# 5                    311.79                 152.72             4045
# 7                    475.20                 118.80             8086
# ...                     ...                    ...              ...
# 49969                266.42                 266.42             4046
# 49973              34539.78                4914.17            24205
# 49981               1109.12                 391.52             6066
# 49994              28771.99                4683.27            24215
# 49998               1916.11                 346.95            12123
#
#        billings_ltm_prorated  cluster
# 2                    1157.72        1
# 3                     478.80        0
# 4                     533.25        1
# 5                     152.72        0
# 7                     118.80        0
# ...                      ...      ...
# 49969                 266.42        0
# 49973                4914.15        1
# 49981                 391.52        0
# 49994                4683.26        1
# 49998                 346.95        0
#
# [18150 rows x 16 columns]
